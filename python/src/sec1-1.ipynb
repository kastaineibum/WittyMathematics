# %%
#一元一次函数 直线
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y1=x1 #替换这里的函数表达式
x2=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y2=x2+3 #替换这里的函数表达式
x3=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y3=2*x3+3 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-10,10) #x轴的刻度范围设置
plt.ylim(-10,10) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-1.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#一元一次函数 斜率动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(-6,6,100) #替换这里的横轴显示范围和取样点个数
y1=x1*0.2 #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'一元一次函数的斜率变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(-3,3) #x轴的刻度范围设置
    plt.ylim(-3,3) #y轴的刻度范围设置
    a=0
    if i<50:
        a=0.2+0.2*-i
        line1.set_ydata(x1*a)
    else:
        a=0.2+0.2*(100-i)
        line1.set_ydata(x1*a)
    #plt.title('k='+str(a), fontsize=14)
    strdisplay = 'k='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:6], fontsize=20)
    return line1,
def init():
    line1.set_ydata(x1*0.2)
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('linearfunction.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_5.gif" width="320">

# %%
#一元二次函数 抛物线
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-10,10,100) #替换这里的横轴显示范围和取样点个数
y1=x1**2+2*x1+1 #替换这里的函数表达式
x2=np.linspace(-10,10,100) #替换这里的横轴显示范围和取样点个数
y2=4*(x2**2)+4*x2+1 #替换这里的函数表达式
x3=np.linspace(-10,10,100) #替换这里的横轴显示范围和取样点个数
y3=-4*(x3**2)+4*x3+3 #替换这里的函数表达式
plt.figure()
#plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-10,10) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-2.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#一元二次函数 系数动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(-5,5,300) #替换这里的横轴显示范围和取样点个数
y1=0.2*(x1**2) #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'一元二次函数的系数变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(-3,3) #x轴的刻度范围设置
    plt.ylim(-3,3) #y轴的刻度范围设置
    a=0.2
    if i<50:
        a=-(0.2+0.2*-i)
        line1.set_ydata(a*(x1**2))
    else:
        a=-(0.2+0.2*(100-i))
        line1.set_ydata(a*(x1**2))
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'A='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:6], fontsize=20)
    return line1,
def init():
    line1.set_ydata(0.2*(x1**2))
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('quadraticfunction.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_11.gif" width="320">

# %%
#倒数函数 双曲线
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y1=1/x1 #替换这里的函数表达式
x2=np.linspace(-10,-0.01,100) #替换这里的横轴显示范围和取样点个数
y2=1/x2 #替换这里的函数表达式
x3=np.linspace(2.01,10,100) #替换这里的横轴显示范围和取样点个数
y3=1/(x3-2)-2 #替换这里的函数表达式
x4=np.linspace(-10,1.99,100) #替换这里的横轴显示范围和取样点个数
y4=1/(x4-2)-2 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-3.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#倒数函数 双曲线
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y1=0.3/x1 #替换这里的函数表达式
x2=np.linspace(-10,-0.01,100) #替换这里的横轴显示范围和取样点个数
y2=0.3/x2 #替换这里的函数表达式
x3=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y3=3/x3 #替换这里的函数表达式
x4=np.linspace(-10,-0.01,100) #替换这里的横轴显示范围和取样点个数
y4=3/x4 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
#倒数函数 系数动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(0.001,5,100) #替换这里的横轴显示范围和取样点个数
y1=0.2/x1 #替换这里的函数表达式
x2=np.linspace(-5,-0.001,100) #替换这里的横轴显示范围和取样点个数
y2=0.2/x2 #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
line2,=pltsub.plot(x2, y2)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'倒数函数的系数变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(-3,3) #x轴的刻度范围设置
    plt.ylim(-3,3) #y轴的刻度范围设置
    a=0.2
    if i<50:
        a=-(0.2+0.2*-i)
        line1.set_ydata(a/x1)
        line2.set_ydata(a/x2)
    else:
        a=-(0.2+0.2*(100-i))
        line1.set_ydata(a/x1)
        line2.set_ydata(a/x2)
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'h='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:6], fontsize=20)
    return line1,
def init():
    line1.set_ydata(0.2/x1)
    line2.set_ydata(0.2/x2)
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('reciprocalfunction.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_10.gif" width="320">

# %%
#倒数函数和一次函数的叠加
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(2.01,20,200) #替换这里的横轴显示范围和取样点个数
y1=0.4*x1+5/(x1-2)+3 #替换这里的函数表达式
x2=np.linspace(-20,1.99,200) #替换这里的横轴显示范围和取样点个数
y2=0.4*x2+5/(x2-2)+3 #替换这里的函数表达式
x3=np.linspace(-20,20,200) #替换这里的横轴显示范围和取样点个数
y3=0.4*x3+3
x4=[2,2]
y4=[-10,10]
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3,'--')
plt.plot(x4, y4,'--')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-10,10) #x轴的刻度范围设置
plt.ylim(-10,10) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-4.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#幂函数
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
#y1=np.sign(x1) * (np.abs(x1)) ** (1.2) #替换这里的函数表达式
y1=(x1) ** (1.2) #替换这里的函数表达式
x2=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y2=np.sign(x2) * (np.abs(x2)) ** (2.4) #替换这里的函数表达式
x3=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y3=np.sign(x3) * (np.abs(x3)) ** (3.6) #替换这里的函数表达式
x4=np.linspace(0.01,10,100) #替换这里的横轴显示范围和取样点个数
y4=np.sign(x4) * (np.abs(x4)) ** (0.7) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.show()

# %%
#幂函数 幂次动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(0,5,100) #替换这里的横轴显示范围和取样点个数
y1=x1**0.1 #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.1

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'幂函数的幂次变化（正值）', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(0,3) #x轴的刻度范围设置
    plt.ylim(0,3) #y轴的刻度范围设置
    a=0.1
    if i<50:
        a=0.1+0.1*i
        line1.set_ydata(x1**a)
    else:
        a=0.1+0.1*(100-i)
        line1.set_ydata(x1**a)
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'a='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:5], fontsize=20)
    return line1,
def init():
    line1.set_ydata(x1**0.1)
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('powerfunction.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_4.gif" width="320">

# %%
#幂函数 幂次动画2
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(0.01,5,100) #替换这里的横轴显示范围和取样点个数
y1=x1**(-0.1) #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=-0.1

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'幂函数的幂次变化（负值）', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(0,3) #x轴的刻度范围设置
    plt.ylim(0,3) #y轴的刻度范围设置
    a=-0.1
    if i<50:
        a=-(0.1+0.1*i)
        line1.set_ydata(x1**a)
    else:
        a=-(0.1+0.1*(100-i))
        line1.set_ydata(x1**a)
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'a='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:6], fontsize=20)
    return line1,
def init():
    line1.set_ydata(x1**(-0.1))
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('powerfunction2.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_6.gif" width="320">

# %% [markdown]
# <img src="./MyVideo_9.gif" width="320">

# %%
#幂函数 幂次动画3
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(0,5,100) #替换这里的横轴显示范围和取样点个数
y1=x1**0.1 #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'幂函数的幂次变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(0,3) #x轴的刻度范围设置
    plt.ylim(0,3) #y轴的刻度范围设置
    a=0.2
    if i<50:
        a=0.2+0.2*-i
        line1.set_ydata(x1**a)
    else:
        a=0.2+0.2*(100-i)
        line1.set_ydata(x1**a)
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'a='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:6], fontsize=20)
    return line1,
def init():
    line1.set_ydata(x1**0.2)
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('powerfunction3.gif',writer='imagemagick')
plt.show()
# Out:
# C:\Users\3mn\anaconda3\lib\site-packages\ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in power

# %%
#指数函数
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y1=2**x1 #替换这里的函数表达式
x2=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y2=5**x2 #替换这里的函数表达式
x3=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y3=0.5**x3 #替换这里的函数表达式
x4=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y4=0.2**x4 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-10,10) #x轴的刻度范围设置
plt.ylim(-10,10) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-5.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#指数函数 底数动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(-5,5,300) #替换这里的横轴显示范围和取样点个数
y1=0.2**x1 #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'指数函数的底数变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(-5,5) #x轴的刻度范围设置
    plt.ylim(0,3) #y轴的刻度范围设置
    a=0
    if i<50:
        a=0.2+0.1*i
        line1.set_ydata(a**x1)
    else:
        a=0.2+0.1*(100-i)
        line1.set_ydata(a**x1)
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'a='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:5], fontsize=20)
    return line1,
def init():
    line1.set_ydata(0.2**x1)
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('exponentialfunction.gif',writer='imagemagick')
plt.show()

# %% [markdown]
# <img src="./MyVideo_7.gif" width="320">

# %%
#对数函数
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(0.01,10,50) #替换这里的横轴显示范围和取样点个数
y1=np.log(x1)/ np.log(2) #替换这里的函数表达式
x2=np.linspace(0.01,10,50) #替换这里的横轴显示范围和取样点个数
y2=np.log(x2)/ np.log(5) #替换这里的函数表达式
x3=np.linspace(0.01,10,50) #替换这里的横轴显示范围和取样点个数
y3=np.log(x3)/ np.log(0.5) #替换这里的函数表达式
x4=np.linspace(0.01,10,50) #替换这里的横轴显示范围和取样点个数
y4=np.log(x4)/ np.log(0.2) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-10,10) #x轴的刻度范围设置
plt.ylim(-7,7) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-6.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#对数函数 底数动画
from matplotlib import animation
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
import matplotlib.patches as mpathes

fig,pltsub=plt.subplots()

x1=np.linspace(0.01,7,300) #替换这里的横轴显示范围和取样点个数
y1=np.log(x1)/np.log(0.2) #替换这里的函数表达式

pltsub.axis('equal')
line1,=pltsub.plot(x1, y1)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

a=0.2

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
plt.title(u'对数函数的底数变化', fontsize=14)
xyrect = np.array([2.4,0.2])
    
def update(i):
    plt.xlim(0,5) #x轴的刻度范围设置
    plt.ylim(-3,3) #y轴的刻度范围设置
    a=0.2
    if i<50:
        a=0.2+0.1*i
        line1.set_ydata(np.log(x1)/np.log(a))
    else:
        a=0.2+0.1*(100-i)
        line1.set_ydata(np.log(x1)/np.log(a))
    #plt.title('a='+str(a), fontsize=14)
    strdisplay = 'a='+str(a)
    plt.text(2.5,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.3,0.3, u"■■■■■■",fontsize=28,color='white')
    plt.text(2.5,0.4, strdisplay[0:5], fontsize=20)
    return line1,
def init():
    line1.set_ydata(np.log(x1)/np.log(0.2))
    return line1,
 
ani=animation.FuncAnimation(fig=fig,func=update,frames=100,init_func=init,interval=20,blit=False)
ani.save('logarithmicfunction.gif',writer='imagemagick')
plt.show()
# Out:
# C:\Users\3mn\anaconda3\lib\site-packages\ipykernel_launcher.py:42: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\3mn\anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# <img src="./MyVideo_8.gif" width="320">

# %%
#三角函数 1 定义
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y1=np.sin(x1) #替换这里的函数表达式
x2=np.linspace(-10,10,50) #替换这里的横轴显示范围和取样点个数
y2=np.cos(x2) #替换这里的函数表达式
x3=np.linspace(-1.57,1.57,50) #替换这里的横轴显示范围和取样点个数
y3=np.tan(x3) #替换这里的函数表达式
x4=np.linspace(-4.71,-1.58,50) #替换这里的横轴显示范围和取样点个数
y4=np.tan(x4) #替换这里的函数表达式
x5=np.linspace(1.58,4.71,50) #替换这里的横轴显示范围和取样点个数
y5=np.tan(x5) #替换这里的函数表达式
x6=np.linspace(4.72,7.85,50) #替换这里的横轴显示范围和取样点个数
y6=np.tan(x6) #替换这里的函数表达式
x7=np.linspace(-7.85,-4.72,50) #替换这里的横轴显示范围和取样点个数
y7=np.tan(x7) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3,'g')
plt.plot(x4, y4,'g')
plt.plot(x5, y5,'g')
plt.plot(x6, y6,'g')
plt.plot(x7, y7,'g')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-10,10) #x轴的刻度范围设置
plt.ylim(-10,10) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-10.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation
 
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号
fig = plt.figure(1)
ax = fig.add_subplot(1, 1, 1, projection='3d')  # 指定三维空间做图
 
t = np.linspace(0, 4, 200)  # 在0到4之间，均匀产生200点的数组
theta = t * 2 * np.pi  # 角度
 
# 生成曲线数组
z = t
x = np.sin(theta)
y = np.cos(theta)
y0 = np.empty(200)
y0.fill(0)
 
# 运动的点
circlepoint, = ax.plot([x[0]], [y[0]], [z[0]], 'ro', label=u'圆周运动的点',color='red')
sinepoint, = ax.plot([x[0]], [y0[0]], [z[0]], 'ro', label=u'投影正弦的点',color='blue')
 
# 曲线
circle, = ax.plot([x[0]], [y[0]], [z[0]], label=u'圆周轨迹',color='red')
sine, = ax.plot([x[0]], [y0[0]], [z[0]], label=u'正弦轨迹',color='blue')
 
# 设置显示的范围和描述
x_min = 0
y_min = 0
z_min = 0
x_max = 1
y_max = 1
z_max = 1
margin = 1
ax.set_xlim(x_min - margin, x_max + margin)
ax.set_ylim(y_min - margin, y_max + margin)
ax.set_zlim(z_min - margin, z_max + margin)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# 标题
ax.set_title(u'推进匀速圆周运动形成的正弦函数')
ax.view_init(30, 35)
# 设置标签在右下角
ax.legend(loc='lower right')
 
 
def animate(i):
    circle.set_xdata(x[:i + 1])
    circle.set_ydata(y[:i + 1])
    circle.set_3d_properties(z[:i + 1])
    circlepoint.set_xdata(x[i])
    circlepoint.set_ydata(y[i])
    circlepoint.set_3d_properties(z[i])
    sine.set_xdata(x[:i + 1])
    sine.set_ydata(y0[:i + 1])
    sine.set_3d_properties(z[:i + 1])
    sinepoint.set_xdata(x[i])
    sinepoint.set_ydata(y0[i])
    sinepoint.set_3d_properties(z[i])
    ax.view_init(azim=i)
 
rot_animation = animation.FuncAnimation(fig, animate, frames=np.arange(0,180+2,2),interval=200)
 
rot_animation.save('sinerealpart.gif', writer='imagemagick')

# %% [markdown]
# <img src="./MyVideo_12.gif" width="320">

# %% [markdown]
# <img src="./MyVideo_1.gif" width="320">

# %% [markdown]
# <img src="./MyVideo_2.gif" width="320">

# %%
#三角函数 2 幂次
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-5,5,100) #替换这里的横轴显示范围和取样点个数
y1=np.sin(x1)**3 #替换这里的函数表达式
x2=np.linspace(-5,5,100) #替换这里的横轴显示范围和取样点个数
y2=np.sin(x2)**18 #替换这里的函数表达式
x3=np.linspace(-5,5,100) #替换这里的横轴显示范围和取样点个数
y3=np.sin(x3)**33 #替换这里的函数表达式
x4=np.linspace(-5,5,100) #替换这里的横轴显示范围和取样点个数
y4=np.sin(x4)**48 #替换这里的函数表达式
x5=np.linspace(-5,5,100) #替换这里的横轴显示范围和取样点个数
y5=np.sin(x5)**63 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
plt.plot(x5, y5)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-1,1) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-13.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#三角函数 3 幂次和角速度
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y1=np.sin(x1)**23 #替换这里的函数表达式
x2=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y2=np.sin(x2*5) #替换这里的函数表达式
x3=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y3=np.sin(x3) #替换这里的函数表达式
x4=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y4=np.sin(x4)**5 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-1,1) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-14.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#三角函数 4 正弦三倍角公式
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y1=np.sin(3*x1) #替换这里的函数表达式
x2=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y2=np.sin(x2)*3 #替换这里的函数表达式
x3=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y3=-4*(np.sin(x3)**3) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-4,4) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-15.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#反三角函数
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-1,1,1000) #替换这里的横轴显示范围和取样点个数
y1=np.arcsin(x1) #替换这里的函数表达式
x2=np.linspace(-1,1,1000) #替换这里的横轴显示范围和取样点个数
y2=np.arccos(x2) #替换这里的函数表达式
x3=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y3=np.arctan(x3) #替换这里的函数表达式
x4=np.linspace(-5,-0.01,1000) #替换这里的横轴显示范围和取样点个数
y4=np.arctan(1/x4)+3.14 #替换这里的函数表达式
x5=np.linspace(0.01,5,1000) #替换这里的横轴显示范围和取样点个数
y5=np.arctan(1/x5) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.plot(x4, y4)
plt.plot(x5, y5,'r')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-4,4) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-16.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#这里是可以直接复制粘贴使用的多边形图像绘制模板
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpathes
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

fig,ax = plt.subplots()
xy1 = np.array([2,2])
xy2 = np.array([-3.9,-2.8])
xy3 = np.array([-3,1.5])
xy4 = np.array([2,-2])
#圆形
circle = mpathes.Circle(xy1,0.8,color='b',fill=False)
ax.add_patch(circle)
#长方形
rect = mpathes.Rectangle(xy2,2.2,1.7,color='r',fill=False)
ax.add_patch(rect)
#多边形
polygon = mpathes.RegularPolygon(xy3,5,1.3,color='g',fill=False)
ax.add_patch(polygon)
#椭圆形
ellipse = mpathes.Ellipse(xy4,2.4,1.9,color='y',fill=False)
ax.add_patch(ellipse)

plt.axis('equal')
plt.grid()

x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-4,4) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.show()

# %%
#圆
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpathes
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

fig,ax = plt.subplots()
xy1 = np.array([0,0])
xy2 = np.array([0.5,0.866])
xy3 = np.array([0.5,0])
circle = mpathes.Circle(xy1,1,color='b',fill=False)
ax.add_patch(circle)
connp = mpathes.ConnectionPatch(xy1,xy2,'data',color='g')
ax.add_patch(connp)
connp2 = mpathes.ConnectionPatch(xy2,xy3,'data',color='g')
ax.add_patch(connp2)

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-2,2) #x轴的刻度范围设置
plt.ylim(-2,2) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.title(u'圆', fontsize=14)
plt.text(0.2, 0.4, r'$\mathcal{1}$', fontsize=20)
plt.text(0.2, -0.15, r'$\mathcal{x}$', fontsize=20)
plt.text(0.5,0.4, r'$\mathcal{y}$', fontsize=20)
plt.text(0.3,0.9, r'$\mathcal{(x,y)}$', fontsize=20)

plt.savefig("./sec1-1-17.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#椭圆
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpathes
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

fig,ax = plt.subplots()
xy1 = np.array([0,0])
xy2 = np.array([1,1])
xy3 = np.array([1.34164,0])
xy4 = np.array([-1.34164,0])
ellipse = mpathes.Ellipse(xy1,3.6,2.4,color='b',fill=False)
ax.add_patch(ellipse)
connp = mpathes.ConnectionPatch(xy4,xy2,'data',color='g')
ax.add_patch(connp)
connp2 = mpathes.ConnectionPatch(xy2,xy3,'data',color='g')
ax.add_patch(connp2)

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-2,2) #x轴的刻度范围设置
plt.ylim(-2,2) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.title(u'椭圆', fontsize=14)
plt.text(-0.4, 0.5, r'$\mathcal{d}_1$', fontsize=20)
plt.text(1.1, -0.2, r'$\mathcal{1.34164}$', fontsize=12)
plt.text(-1.7, -0.2, r'$\mathcal{-1.34164}$', fontsize=12)
plt.text(1.15,0.45, r'$\mathcal{d}_2$', fontsize=20)
plt.text(0.8,1.1, r'$\mathcal{(x,y)}$', fontsize=20)
plt.text(0.05, 1.1, r'$\mathcal{b}$', fontsize=20)
plt.text(1.75, -0.15, r'$\mathcal{a}$', fontsize=20)

plt.savefig("./sec1-1-19.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#椭圆 准线
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpathes
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

fig,ax = plt.subplots()
xy1 = np.array([0,0])
xy2 = np.array([1,1])
xy3 = np.array([1.34164,0])
xy4 = np.array([2.415,2])
xy5 = np.array([2.415,-2])
xy6 = np.array([2.415,1])
ellipse = mpathes.Ellipse(xy1,3.6,2.4,color='b',fill=False)
ax.add_patch(ellipse)
connp = mpathes.ConnectionPatch(xy4,xy5,'data',color='r')
ax.add_patch(connp)
connp2 = mpathes.ConnectionPatch(xy2,xy3,'data',color='g')
ax.add_patch(connp2)
connp3 = mpathes.ConnectionPatch(xy2,xy6,'data',color='g')
ax.add_patch(connp3)

plt.axis('equal')
plt.grid()
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-3,3) #x轴的刻度范围设置
plt.ylim(-2,2) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.title(u'椭圆', fontsize=14)
plt.text(1.8, 0.8, r'$\mathcal{d}_2$', fontsize=20)
plt.text(1.1, -0.2, r'$\mathcal{1.34164}$', fontsize=12)
plt.text(-1.7, -0.2, r'$\mathcal{-1.34164}$', fontsize=12)
plt.text(1.15,0.45, r'$\mathcal{d}_1$', fontsize=20)
plt.text(0.8,1.1, r'$\mathcal{(x,y)}$', fontsize=20)

plt.savefig("./sec1-1-20.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# 丹德林球体<img src="./MyVideo_3.gif" width="320">

# %%
#坐标的对数变换
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(1,5,100) #替换这里的横轴显示范围和取样点个数
y1=x1 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1,'b')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.text(1, 0.5, r'$\mathcal{y=x}$', fontsize=20)
plt.text(4.8, -0.8, r'$\mathcal{x}$', fontsize=20)

plt.savefig("./sec1-1-24-1.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#坐标的对数变换
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(0,5,100) #替换这里的横轴显示范围和取样点个数
y1=np.e**x1 #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1,'b')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.text(1, 1.5, r'$\mathcal{y=x}$', fontsize=20)
plt.text(3.8, -1.5, r'$\mathcal{m(m=ln x)}$', fontsize=20)

plt.savefig("./sec1-1-24-2.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
#双曲函数
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

x1=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y1=np.sinh(x1) #替换这里的函数表达式
x2=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y2=np.cosh(x2) #替换这里的函数表达式
x3=np.linspace(-5,5,1000) #替换这里的横轴显示范围和取样点个数
y3=np.tanh(x2) #替换这里的函数表达式
plt.figure()
plt.axis('equal')
plt.plot(x1, y1,'b')
plt.plot(x2, y2,'r')
plt.plot(x3, y3,'orange')
x_major_locator=MultipleLocator(1) #把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(1) #把y轴的刻度间隔设置为1，并存在变量里
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)#把y轴的主刻度设置为1的倍数
plt.xlim(-5,5) #x轴的刻度范围设置
plt.ylim(-5,5) #y轴的刻度范围设置
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.savefig("./sec1-1-25.png",dpi=500,bbox_inches = 'tight')
plt.show()
